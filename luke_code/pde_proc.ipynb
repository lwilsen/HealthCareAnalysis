# %%
import pandas as pd
import numpy as np
np.set_printoptions(threshold=np.inf)
import matplotlib.pyplot as plt
import seaborn as sns
from google.colab import drive
from datetime import datetime
import os
import datetime

drive.flush_and_unmount()
drive.mount('/content/drive')
# !ls drive/MyDrive/BS_696/
# Out:
# Mounted at /content/drive
# BS_696_data_processing.ipynb  data		    Enrollment_proc.ipynb
# BS_696_Notes.gdoc	      diagnosis_proc.ipynb  utils.ipynb

# %%
# !ls drive/MyDrive/BS_696/data

pde = pd.read_csv('drive/MyDrive/BS_696/data/pde.csv', sep = '|')
# Out:
# 'All Beneficiary Years'   ICD_10_CM_codes_2025.txt   MS-DRG-1023.xlsx
#  all_bene_years_raw.csv   inpatient.csv		     MSDRG_FY_2025.txt
#  diagnosis.csv		  inpatient_encounters.csv   pde.csv
# <ipython-input-11-670255ea6469>:3: DtypeWarning: Columns (20) have mixed types. Specify dtype option on import or set low_memory=False.
#   pde = pd.read_csv('drive/MyDrive/BS_696/data/pde.csv', sep = '|')

# %%
pde.infomn()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 515520 entries, 0 to 515519
# Data columns (total 36 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   PDE_ID               515520 non-null  int64
#  1   BENE_ID              515520 non-null  int64
#  2   SRVC_DT              515520 non-null  object
#  3   PD_DT                515520 non-null  object
#  4   PRSCRBR_ID_QLFYR_CD  515520 non-null  int64
#  5   PRSCRBR_ID           515520 non-null  int64
#  6   RX_SRVC_RFRNC_NUM    515520 non-null  int64
#  7   PROD_SRVC_ID         515520 non-null  int64
#  8   PLAN_CNTRCT_REC_ID   515520 non-null  object
#  9   PLAN_PBP_REC_NUM     515520 non-null  int64
#  10  CMPND_CD             515520 non-null  int64
#  11  DAW_PROD_SLCTN_CD    515520 non-null  int64
#  12  QTY_DSPNSD_NUM       515520 non-null  int64
#  13  DAYS_SUPLY_NUM       515520 non-null  int64
#  14  FILL_NUM             515520 non-null  int64
#  15  DSPNSNG_STUS_CD      515520 non-null  object
#  16  DRUG_CVRG_STUS_CD    515520 non-null  object
#  17  ADJSTMT_DLTN_CD      515520 non-null  object
#  18  NSTD_FRMT_CD         515520 non-null  object
#  19  PRCNG_EXCPTN_CD      0 non-null       float64
#  20  CTSTRPHC_CVRG_CD     15538 non-null   object
#  21  GDC_BLW_OOPT_AMT     515520 non-null  float64
#  22  GDC_ABV_OOPT_AMT     515520 non-null  float64
#  23  PTNT_PAY_AMT         515520 non-null  float64
#  24  OTHR_TROOP_AMT       515520 non-null  int64
#  25  LICS_AMT             515520 non-null  int64
#  26  PLRO_AMT             515520 non-null  float64
#  27  CVRD_D_PLAN_PD_AMT   515520 non-null  float64
#  28  NCVRD_PLAN_PD_AMT    515520 non-null  float64
#  29  TOT_RX_CST_AMT       515520 non-null  float64
#  30  RX_ORGN_CD           515520 non-null  int64
#  31  RPTD_GAP_DSCNT_NUM   515520 non-null  int64
#  32  BRND_GNRC_CD         515520 non-null  object
#  33  PHRMCY_SRVC_TYPE_CD  515520 non-null  int64
#  34  PTNT_RSDNC_CD        515520 non-null  int64
#  35  SUBMSN_CLR_CD        0 non-null       float64
# dtypes: float64(9), int64(18), object(9)
# memory usage: 141.6+ MB
